# %%
from classiq import *
import numpy as np

# %%
@qfunc
def prepare_initial(q: QBit) -> None:
    H(q)    # hadamard gate prepares (|0> + |1>) / sqrt(2)

@qfunc
def apply_M(q: QBit, t: CReal):
    # M = [[0,1],[-1,0]] acts like a rotation
    RY(2*t, q)  # Roughly rotates |0> to |1> and |1> to -|0>  

@qfunc
def main(q: Output[QBit], t: CReal):
    allocate(q)
    prepare_initial(q)
    apply_M(q, t)    

qmod = create_model(main)

# %%
from classiq import ExecutionSession

qprog = synthesize(qmod)

# parameter list: one dict for each time
times = np.linspace(0, 1, 20)
params_list = [{"t": float(t)} for t in times]

# execute in a session
with ExecutionSession(qprog) as session:
    batch_results = session.batch_sample(params_list)

# %%
print(qmod)
# Out:
# {
#   "source_ref": null,
#   "back_ref": null,
#   "interface_version": "17",
#   "kind": "user",
#   "functions": [
#     {
#       "source_ref": null,
#       "back_ref": null,
#       "name": "prepare_initial_expanded___0",
#       "positional_arg_declarations": [
#         {
#           "source_ref": null,
#           "back_ref": null,
#           "name": "q",
#           "quantum_type": {
#             "source_ref": null,
#             "back_ref": null,
#             "kind": "qbit"
#           },
#           "direction": "inout",
#           "kind": "PortDeclaration",
#           "type_modifier": "mutable"
#         }
#       ],
#       "permutation": false,
#       "body": [
#         {
#           "source_ref": {
#             "start_line": 2,
#             "start_column": 3,
#             "end_line": 2,
#             "end_column": 7,
#             "file_name": "C:\\Users\\natha\\AppData\\Local\\Temp\\ipykernel_11288\\2855906989.py"
#           },
#           "back_ref": "93b00b95-e791-4219-b59a-02c06cba16a3",
#           "kind": "QuantumFunctionCall",
#           "uuid": "1f595092-ef79-48a7-8e7d-f260e7114ea9",
#           "function": "H",
#           "positional_args": [
#             {
#               "source_ref": null,
#               "back_ref": null,
#               "name": "q"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "source_ref": null,
#       "back_ref": null,
#       "name": "apply_M_expanded___0",
#       "positional_arg_declarations": [
#         {
#           "source_ref": null,
#           "back_ref": null,
#           "name": "q",
#           "quantum_type": {
#             "source_ref": null,
#             "back_ref": null,
#             "kind": "qbit"
#           },
#           "direction": "inout",
#           "kind": "PortDeclaration",
#           "type_modifier": "mutable"
#         },
#         {
#           "source_ref": null,
#           "back_ref": null,
#           "name": "t",
#           "kind": "ClassicalParameterDeclaration",
#           "classical_type": {
#             "source_ref": null,
#             "back_ref": null,
#             "kind": "real"
#           }
#         }
#       ],
#       "permutation": false,
#       "body": [
#         {
#           "source_ref": {
#             "start_line": 7,
#             "start_column": 3,
#             "end_line": 7,
#             "end_column": 13,
#             "file_name": "C:\\Users\\natha\\AppData\\Local\\Temp\\ipykernel_11288\\2855906989.py"
#           },
#           "back_ref": "e926f67a-8834-4eb4-bf5e-a63c224a7506",
#           "kind": "QuantumFunctionCall",
#           "uuid": "4c403412-4575-49e9-888e-5a7a8055d61a",
#           "function": "RY",
#           "positional_args": [
#             {
#               "source_ref": null,
#               "back_ref": null,
#               "expr": "2 * t"
#             },
#             {
#               "source_ref": null,
#               "back_ref": null,
#               "name": "q"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "source_ref": null,
#       "back_ref": null,
#       "name": "main",
#       "positional_arg_declarations": [
#         {
#           "source_ref": null,
#           "back_ref": null,
#           "name": "q",
#           "quantum_type": {
#             "source_ref": null,
#             "back_ref": null,
#             "kind": "qbit"
#           },
#           "direction": "output",
#           "kind": "PortDeclaration",
#           "type_modifier": "mutable"
#         },
#         {
#           "source_ref": null,
#           "back_ref": null,
#           "name": "t",
#           "kind": "ClassicalParameterDeclaration",
#           "classical_type": {
#             "source_ref": null,
#             "back_ref": null,
#             "kind": "real"
#           }
#         }
#       ],
#       "permutation": false,
#       "body": [
#         {
#           "source_ref": {
#             "start_line": 11,
#             "start_column": 3,
#             "end_line": 11,
#             "end_column": 14,
#             "file_name": "C:\\Users\\natha\\AppData\\Local\\Temp\\ipykernel_11288\\2855906989.py"
#           },
#           "back_ref": null,
#           "kind": "Allocate",
#           "uuid": "21e56f39-8521-4059-84ec-562ba8ca0869",
#           "size": {
#             "source_ref": null,
#             "back_ref": null,
#             "expr": "1"
#           },
#           "is_signed": null,
#           "fraction_digits": null,
#           "target": {
#             "source_ref": null,
#             "back_ref": null,
#             "name": "q"
#           }
#         },
#         {
#           "source_ref": {
#             "start_line": 12,
#             "start_column": 3,
#             "end_line": 12,
#             "end_column": 21,
#             "file_name": "C:\\Users\\natha\\AppData\\Local\\Temp\\ipykernel_11288\\2855906989.py"
#           },
#           "back_ref": "9bbaf43a-1fb8-47bc-a360-0035b2272ddc",
#           "kind": "QuantumFunctionCall",
#           "uuid": "0e1aec7d-16ab-4f87-a2e7-f69c4293eccb",
#           "function": "prepare_initial_expanded___0",
#           "positional_args": [
#             {
#               "source_ref": null,
#               "back_ref": null,
#               "name": "q"
#             }
#           ]
#         },
#         {
#           "source_ref": {
#             "start_line": 13,
#             "start_column": 3,
#             "end_line": 13,
#             "end_column": 16,
#             "file_name": "C:\\Users\\natha\\AppData\\Local\\Temp\\ipykernel_11288\\2855906989.py"
#           },
#           "back_ref": "25a77ce7-7722-416a-9141-73cf83c6b150",
#           "kind": "QuantumFunctionCall",
#           "uuid": "b98f68b4-afe5-4956-b8a2-bf9abd22d18e",
#           "function": "apply_M_expanded___0",
#           "positional_args": [
#             {
#               "source_ref": null,
#               "back_ref": null,
#               "name": "q"
#             },
#             {
#               "source_ref": null,
#               "back_ref": null,
#               "expr": "t"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "enums": [],
#   "types": [],
#   "qstructs": [],
#   "classical_execution_code": "",
#   "constants": [],
#   "constraints": {
#     "max_width": null,
#     "max_depth": null,
#     "max_gate_count": {},
#     "optimization_parameter": "no_opt"
#   },
#   "execution_preferences": {
#     "noise_properties": null,
#     "random_seed": 3464763879,
#     "backend_preferences": {
#       "backend_service_provider": "Classiq",
#       "backend_name": "simulator"
#     },
#     "num_shots": null,
#     "transpile_to_hardware": "decompose",
#     "job_name": null,
#     "include_zero_amplitude_outputs": false
#   },
#   "preferences": {
#     "machine_precision": 8,
#     "backend_service_provider": null,
#     "backend_name": null,
#     "custom_hardware_settings": {
#       "basis_gates": [
#         "ry",
#         "r",
#         "u2",
#         "id",
#         "x",
#         "z",
#         "rx",
#         "sdg",
#         "u",
#         "u1",
#         "cx",
#         "s",
#         "u3",
#         "rz",
#         "cz",
#         "sxdg",
#         "sx",
#         "tdg",
#         "p",
#         "t",
#         "cy",
#         "h",
#         "y"
#       ],
#       "connectivity_map": null,
#       "is_symmetric_connectivity": true
#     },
#     "debug_mode": true,
#     "synthesize_all_separately": false,
#     "optimization_level": 1,
#     "output_format": [
#       "qasm"
#     ],
#     "pretty_qasm": true,
#     "qasm3": null,
#     "transpilation_option": "auto optimize",
#     "solovay_kitaev_max_iterations": null,
#     "timeout_seconds": 300,
#     "optimization_timeout_seconds": null,
#     "random_seed": 2704459989,
#     "symbolic_loops": false
#   },
#   "compressed_debug_info": "...",
#   "functions_compilation_metadata": {}
# }
